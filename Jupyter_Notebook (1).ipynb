# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Nathan Cagle**
#   Chemist

# %% [markdown]
# *I am interested in data science, because I want to change my career path to be adjacent to healthcare and technology.

# %% [markdown]
# ### The following code will print out the answer of 3 squared ("9").

# %%
x = 3**2
print(x)
# Out:
# 9

# %% [markdown]
# ---
# - Bunnies
# - Otters
# - Chinchillas
# ---
# ![image.png](attachment:b78777cd-a41c-4ea4-bfd8-8f37ed7db1eb.png
